# %% [markdown]
# Generate an array of zeroes using inbuilt numpy function

# %%
import numpy as np
print( np.zeros( (2,4)))
# Out:
# [[0. 0. 0. 0.]
#  [0. 0. 0. 0.]]

# %% [markdown]
#  Run the given code and find the dot product of both arrays

# %%
import numpy as np
a = np.random.randint(2,10, (3,4))
b = np.random.randint(2,10, (4,3))

dotproduct = np.dot(a,b)

print(dotproduct)
# Out:
# [[ 83 102 119]
#  [ 96 129 126]
#  [ 90 104 128]]

# %%
a.dot(b)
# Out:
# array([[ 83, 102, 119],
#        [ 96, 129, 126],
#        [ 90, 104, 128]])

# %%
dotproduct = np.dot(a,b)

print(dotproduct)
# Out:
# [[ 83 102 119]
#  [ 96 129 126]
#  [ 90 104 128]]

# %% [markdown]
# Read the csv file provided using pandas and display the first 5 entries

# %%
import numpy as np 
import pandas as pd

# %%
Assigment_data = 'data.csv'

# %%
data = pd.read_csv('data.csv')

# %%
data.head(5)
# Out:
#    OBJECTID                        UNIT_NAME DESCRIPTION   ACRES  SHAPE.AREA  \
# 0        21        Fort Stevenson State Park  State Park  586.48    0.000284
# 1        22           Beaver Lake State Park  State Park  273.16    0.000129
# 2        23  Fort Abraham Lincoln State Park  State Park  836.47    0.000399
# 3        24           Fort Ransom State Park  State Park  933.78    0.000444
# 4        25        Grahams Island State Park  State Park  959.33    0.000469
#
#    SHAPE.LEN
# 0   0.135641
# 1   0.080067
# 2   0.119868
# 3   0.128733
# 4   0.125546

# %% [markdown]
# Describe the data with all features

# %%
data.describe()
# Out:
#         OBJECTID        ACRES  SHAPE.AREA  SHAPE.LEN
# count  25.000000    25.000000   25.000000  25.000000
# mean   33.000000   724.134400    0.000352   0.109863
# std     7.359801  1275.490247    0.000617   0.089073
# min    21.000000    11.400000    0.000005   0.009396
# 25%    27.000000    72.300000    0.000034   0.033885
# 50%    33.000000   524.810000    0.000256   0.087192
# 75%    39.000000   836.470000    0.000399   0.145220
# max    45.000000  6492.930000    0.003136   0.338800

# %%
Find the total count of missing values for each feature

# %%
data.describe(include= 'all')
# Out:
#          OBJECTID                  UNIT_NAME DESCRIPTION        ACRES  \
# count   25.000000                         25          25    25.000000
# unique        NaN                         25           5          NaN
# top           NaN  Fort Stevenson State Park  State Park          NaN
# freq          NaN                          1          13          NaN
# mean    33.000000                        NaN         NaN   724.134400
# std      7.359801                        NaN         NaN  1275.490247
# min     21.000000                        NaN         NaN    11.400000
# 25%     27.000000                        NaN         NaN    72.300000
# 50%     33.000000                        NaN         NaN   524.810000
# 75%     39.000000                        NaN         NaN   836.470000
# max     45.000000                        NaN         NaN  6492.930000
#
#         SHAPE.AREA  SHAPE.LEN
# count    25.000000  25.000000
# unique         NaN        NaN
# top            NaN        NaN
# freq           NaN        NaN
# mean      0.000352   0.109863
# std       0.000617   0.089073
# min       0.000005   0.009396
# 25%       0.000034   0.033885
# 50%       0.000256   0.087192
# 75%       0.000399   0.145220
# max       0.003136   0.338800

# %%
data.isnull().sum()
# Out:
# OBJECTID       0
# UNIT_NAME      0
# DESCRIPTION    0
# ACRES          0
# SHAPE.AREA     0
# SHAPE.LEN      0
# dtype: int64

# %% [markdown]
# Display all the unique values from the 'DESCRIPTION’ column.

# %%
data.loc[:,"DESCRIPTION"].unique()
# Out:
# array(['State Park', 'Interpretive Center', 'State Recreation Area',
#        'State Natural Area', 'State Nature Preserve'], dtype=object)

# %% [markdown]
# Create a grouped table usin 'DESCRIPTION' as the grouping columns with the means of all the other columns.

# %%
data.groupby('DESCRIPTION').mean()
# Out:
#                         OBJECTID        ACRES  SHAPE.AREA  SHAPE.LEN
# DESCRIPTION
# Interpretive Center    29.000000    14.710000    0.000007   0.016774
# State Natural Area     39.000000   219.615000    0.000105   0.077137
# State Nature Preserve  39.500000    84.095000    0.000041   0.037175
# State Park             28.538462  1168.668462    0.000567   0.150326
# State Recreation Area  38.285714   326.934286    0.000162   0.078135

# %%
Generate a random sample of 10 rows from the data

# %%
data.sample(n = 10)
# Out:
#     OBJECTID                              UNIT_NAME            DESCRIPTION  \
# 20        41      Missouri River State Natural Area     State Natural Area
# 8         29    Lewis and Clark Interpretive Center    Interpretive Center
# 7         28             Lewis and Clark State Park             State Park
# 16        37             Elkhorn State Natural Area     State Natural Area
# 5         26                   Icelandic State Park             State Park
# 1         22                 Beaver Lake State Park             State Park
# 12        35   Butte St. Paul State Recreation Area  State Recreation Area
# 0         21              Fort Stevenson State Park             State Park
# 21        43    Pembina Gorge State Recreation Area  State Recreation Area
# 22        44  Turtle Mountain State Recreation Area  State Recreation Area
#
#       ACRES  SHAPE.AREA  SHAPE.LEN
# 20   174.39    0.000083   0.087192
# 8     14.71    0.000007   0.016774
# 7    524.81    0.000256   0.130420
# 16   264.84    0.000127   0.067082
# 5    930.30    0.000461   0.166712
# 1    273.16    0.000129   0.080067
# 12    51.23    0.000025   0.022095
# 0    586.48    0.000284   0.135641
# 21  1236.98    0.000615   0.338800
# 22   695.04    0.000345   0.086487

# %% [markdown]
# Add a Feature called 'New_feature' to the new Dataset and Add Random float Values in between 0 and 1 using Numpy

# %%
data['New_featuer'] = np.random.rand(data.shape[0])
print(data)
# Out:
#     OBJECTID                                   UNIT_NAME  \
# 0         21                   Fort Stevenson State Park
# 1         22                      Beaver Lake State Park
# 2         23             Fort Abraham Lincoln State Park
# 3         24                      Fort Ransom State Park
# 4         25                   Grahams Island State Park
# 5         26                        Icelandic State Park
# 6         27                   Lake Metigoshe State Park
# 7         28                  Lewis and Clark State Park
# 8         29         Lewis and Clark Interpretive Center
# 9         30           Fort Mandan State Recreation Area
# 10        31                  Little Missouri State Park
# 11        32                      Sully Creek State Park
# 12        35        Butte St. Paul State Recreation Area
# 13        36       Crow Flies High State Recreation Area
# 14        33                     Turtle River State Park
# 15        34                   Lake Sakakawea State Park
# 16        37                  Elkhorn State Natural Area
# 17        38         Fahlgren Park State Recreation Area
# 18        39             Gunlogson State Nature Preserve
# 19        40  Head of the Mountain State Nature Preserve
# 20        41           Missouri River State Natural Area
# 21        43         Pembina Gorge State Recreation Area
# 22        44       Turtle Mountain State Recreation Area
# 23        45                      Cross Ranch State Park
# 24        42         Pelican Point State Recreation Area
#
#               DESCRIPTION    ACRES  SHAPE.AREA  SHAPE.LEN  New_featuer
# 0              State Park   586.48    0.000284   0.135641     0.338176
# 1              State Park   273.16    0.000129   0.080067     0.188924
# 2              State Park   836.47    0.000399   0.119868     0.044846
# 3              State Park   933.78    0.000444   0.128733     0.178390
# 4              State Park   959.33    0.000469   0.125546     0.572206
# 5              State Park   930.30    0.000461   0.166712     0.487523
# 6              State Park  1508.53    0.000751   0.212196     0.668633
# 7              State Park   524.81    0.000256   0.130420     0.095765
# 8     Interpretive Center    14.71    0.000007   0.016774     0.632982
# 9   State Recreation Area    11.40    0.000005   0.009396     0.488997
# 10             State Park  6492.93    0.003136   0.313756     0.281327
# 11             State Park    63.03    0.000030   0.024016     0.136902
# 12  State Recreation Area    51.23    0.000025   0.022095     0.389521
# 13  State Recreation Area   247.11    0.000120   0.050518     0.617736
# 14             State Park   775.28    0.000378   0.145220     0.636361
# 15             State Park   739.52    0.000357   0.191806     0.699543
# 16     State Natural Area   264.84    0.000127   0.067082     0.990455
# 17  State Recreation Area    21.56    0.000010   0.013294     0.621872
# 18  State Nature Preserve    95.89    0.000048   0.040465     0.045980
# 19  State Nature Preserve    72.30    0.000034   0.033885     0.210181
# 20     State Natural Area   174.39    0.000083   0.087192     0.741785
# 21  State Recreation Area  1236.98    0.000615   0.338800     0.247553
# 22  State Recreation Area   695.04    0.000345   0.086487     0.808419
# 23             State Park   569.07    0.000274   0.180257     0.988599
# 24  State Recreation Area    25.22    0.000013   0.026357     0.115832

# %% [markdown]
# Replace zero value of column 'OBJECTID' with mean value permanently

# %%
data.OBJECTID = data.OBJECTID.mask(data.OBJECTID==0).fillna(data.OBJECTID.mean()).astype(int)
print(data)
# Out:
#     OBJECTID                                   UNIT_NAME  \
# 0         21                   Fort Stevenson State Park
# 1         22                      Beaver Lake State Park
# 2         23             Fort Abraham Lincoln State Park
# 3         24                      Fort Ransom State Park
# 4         25                   Grahams Island State Park
# 5         26                        Icelandic State Park
# 6         27                   Lake Metigoshe State Park
# 7         28                  Lewis and Clark State Park
# 8         29         Lewis and Clark Interpretive Center
# 9         30           Fort Mandan State Recreation Area
# 10        31                  Little Missouri State Park
# 11        32                      Sully Creek State Park
# 12        35        Butte St. Paul State Recreation Area
# 13        36       Crow Flies High State Recreation Area
# 14        33                     Turtle River State Park
# 15        34                   Lake Sakakawea State Park
# 16        37                  Elkhorn State Natural Area
# 17        38         Fahlgren Park State Recreation Area
# 18        39             Gunlogson State Nature Preserve
# 19        40  Head of the Mountain State Nature Preserve
# 20        41           Missouri River State Natural Area
# 21        43         Pembina Gorge State Recreation Area
# 22        44       Turtle Mountain State Recreation Area
# 23        45                      Cross Ranch State Park
# 24        42         Pelican Point State Recreation Area
#
#               DESCRIPTION    ACRES  SHAPE.AREA  SHAPE.LEN  New_featuer
# 0              State Park   586.48    0.000284   0.135641     0.628771
# 1              State Park   273.16    0.000129   0.080067     0.108989
# 2              State Park   836.47    0.000399   0.119868     0.799050
# 3              State Park   933.78    0.000444   0.128733     0.084905
# 4              State Park   959.33    0.000469   0.125546     0.194761
# 5              State Park   930.30    0.000461   0.166712     0.839460
# 6              State Park  1508.53    0.000751   0.212196     0.038541
# 7              State Park   524.81    0.000256   0.130420     0.836247
# 8     Interpretive Center    14.71    0.000007   0.016774     0.130335
# 9   State Recreation Area    11.40    0.000005   0.009396     0.777300
# 10             State Park  6492.93    0.003136   0.313756     0.337052
# 11             State Park    63.03    0.000030   0.024016     0.318242
# 12  State Recreation Area    51.23    0.000025   0.022095     0.631796
# 13  State Recreation Area   247.11    0.000120   0.050518     0.316508
# 14             State Park   775.28    0.000378   0.145220     0.048196
# 15             State Park   739.52    0.000357   0.191806     0.180006
# 16     State Natural Area   264.84    0.000127   0.067082     0.008948
# 17  State Recreation Area    21.56    0.000010   0.013294     0.295978
# 18  State Nature Preserve    95.89    0.000048   0.040465     0.312466
# 19  State Nature Preserve    72.30    0.000034   0.033885     0.292918
# 20     State Natural Area   174.39    0.000083   0.087192     0.131782
# 21  State Recreation Area  1236.98    0.000615   0.338800     0.263392
# 22  State Recreation Area   695.04    0.000345   0.086487     0.804402
# 23             State Park   569.07    0.000274   0.180257     0.384402
# 24  State Recreation Area    25.22    0.000013   0.026357     0.304747

# %%
data.OBJECTID.mean()
# Out:
# 33.0

# %%
data.describe(include=[object])
# Out:
#                         UNIT_NAME DESCRIPTION
# count                          25          25
# unique                         25           5
# top     Fort Stevenson State Park  State Park
# freq                            1          13

# %%
data.describe(include= 'all')
# Out:
#          OBJECTID                  UNIT_NAME DESCRIPTION        ACRES  \
# count   25.000000                         25          25    25.000000
# unique        NaN                         25           5          NaN
# top           NaN  Fort Stevenson State Park  State Park          NaN
# freq          NaN                          1          13          NaN
# mean    33.000000                        NaN         NaN   724.134400
# std      7.359801                        NaN         NaN  1275.490247
# min     21.000000                        NaN         NaN    11.400000
# 25%     27.000000                        NaN         NaN    72.300000
# 50%     33.000000                        NaN         NaN   524.810000
# 75%     39.000000                        NaN         NaN   836.470000
# max     45.000000                        NaN         NaN  6492.930000
#
#         SHAPE.AREA  SHAPE.LEN  New_featuer
# count    25.000000  25.000000    25.000000
# unique         NaN        NaN          NaN
# top            NaN        NaN          NaN
# freq           NaN        NaN          NaN
# mean      0.000352   0.109863     0.362768
# std       0.000617   0.089073     0.275531
# min       0.000005   0.009396     0.008948
# 25%       0.000034   0.033885     0.131782
# 50%       0.000256   0.087192     0.304747
# 75%       0.000399   0.145220     0.628771
# max       0.003136   0.338800     0.839460

# %%
data
# Out:
#     OBJECTID                                   UNIT_NAME  \
# 0         21                   Fort Stevenson State Park
# 1         22                      Beaver Lake State Park
# 2         23             Fort Abraham Lincoln State Park
# 3         24                      Fort Ransom State Park
# 4         25                   Grahams Island State Park
# 5         26                        Icelandic State Park
# 6         27                   Lake Metigoshe State Park
# 7         28                  Lewis and Clark State Park
# 8         29         Lewis and Clark Interpretive Center
# 9         30           Fort Mandan State Recreation Area
# 10        31                  Little Missouri State Park
# 11        32                      Sully Creek State Park
# 12        35        Butte St. Paul State Recreation Area
# 13        36       Crow Flies High State Recreation Area
# 14        33                     Turtle River State Park
# 15        34                   Lake Sakakawea State Park
# 16        37                  Elkhorn State Natural Area
# 17        38         Fahlgren Park State Recreation Area
# 18        39             Gunlogson State Nature Preserve
# 19        40  Head of the Mountain State Nature Preserve
# 20        41           Missouri River State Natural Area
# 21        43         Pembina Gorge State Recreation Area
# 22        44       Turtle Mountain State Recreation Area
# 23        45                      Cross Ranch State Park
# 24        42         Pelican Point State Recreation Area
#
#               DESCRIPTION    ACRES  SHAPE.AREA  SHAPE.LEN  New_featuer
# 0              State Park   586.48    0.000284   0.135641     0.628771
# 1              State Park   273.16    0.000129   0.080067     0.108989
# 2              State Park   836.47    0.000399   0.119868     0.799050
# 3              State Park   933.78    0.000444   0.128733     0.084905
# 4              State Park   959.33    0.000469   0.125546     0.194761
# 5              State Park   930.30    0.000461   0.166712     0.839460
# 6              State Park  1508.53    0.000751   0.212196     0.038541
# 7              State Park   524.81    0.000256   0.130420     0.836247
# 8     Interpretive Center    14.71    0.000007   0.016774     0.130335
# 9   State Recreation Area    11.40    0.000005   0.009396     0.777300
# 10             State Park  6492.93    0.003136   0.313756     0.337052
# 11             State Park    63.03    0.000030   0.024016     0.318242
# 12  State Recreation Area    51.23    0.000025   0.022095     0.631796
# 13  State Recreation Area   247.11    0.000120   0.050518     0.316508
# 14             State Park   775.28    0.000378   0.145220     0.048196
# 15             State Park   739.52    0.000357   0.191806     0.180006
# 16     State Natural Area   264.84    0.000127   0.067082     0.008948
# 17  State Recreation Area    21.56    0.000010   0.013294     0.295978
# 18  State Nature Preserve    95.89    0.000048   0.040465     0.312466
# 19  State Nature Preserve    72.30    0.000034   0.033885     0.292918
# 20     State Natural Area   174.39    0.000083   0.087192     0.131782
# 21  State Recreation Area  1236.98    0.000615   0.338800     0.263392
# 22  State Recreation Area   695.04    0.000345   0.086487     0.804402
# 23             State Park   569.07    0.000274   0.180257     0.384402
# 24  State Recreation Area    25.22    0.000013   0.026357     0.304747
